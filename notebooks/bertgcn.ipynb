# %%
# !git clone https://github.com/Dehan001/Bangla_BERTGCN
# Out:
# Cloning into 'experiment5-2'...
# remote: Enumerating objects: 350, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 350 (delta 37), reused 41 (delta 20), pack-reused 288
# Receiving objects: 100% (350/350), 87.72 MiB | 5.87 MiB/s, done.
# Resolving deltas: 100% (213/213), done.
# Updating files: 100% (70/70), done.

# %%
# !ls
# Out:
# __notebook__.ipynb  experiment5-2

# %%
# %cd Bangla_BERTGCN
# Out:
# /kaggle/working/experiment5-2

# %%
# !ls
# Out:
# README.md	 data		   model	      utils
# build_graph.py	 extra.py	   requirements.txt
# build_graph1.py  finetune_bert.py  train_bert_gcn.py

# %%
ls
# Out:
# README.md        data/             model/             utils/
# build_graph.py   extra.py          requirements.txt
# build_graph1.py  finetune_bert.py  train_bert_gcn.py

# %%
# !pwd
# Out:
# /kaggle/working/experiment5-2

# %%
# !pip install ignite pytorch-ignite

# %%
# !pip install dgl -f https://data.dgl.ai/wheels/cu110/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/cu110/repo.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 54.7 MB/s eta 0:00:00
# ...

# %%
# !python3 build_graph.py 'Sentiment'
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...

# %%
# !python finetune_bert.py --dataset "Sentiment"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# ...

# %%
# !python3 finetune_bert.py -h
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
import os
os.environ['DGLBACKEND'] = 'pytorch'

# %%
# !pip install dgl==1.1.1+cu118 -f https://data.dgl.ai/wheels/cu118/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/cu118/repo.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 MB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: dgl
#     Found existing installation: dgl 1.1.2
#     Uninstalling dgl-1.1.2:
#       Successfully uninstalled dgl-1.1.2
# ...

# %%
# !python3 train_bert_gcn.py --dataset "Sentiment" --pretrained_bert_ckpt "/kaggle/working/experiment5-2/checkpoint/csebuetnlp/banglabert_Sentiment/checkpoint.pth" -m 0.3
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
# !python3 train_bert_gcn.py --gcn_model 'gat' --dataset "Sentiment" --pretrained_bert_ckpt "/kaggle/working/experiment5-2/checkpoint/csebuetnlp/banglabert_Sentiment/checkpoint.pth" -m 0.3
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...
